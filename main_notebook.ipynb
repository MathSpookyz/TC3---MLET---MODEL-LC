# %% [markdown]
# # KMeans Clustering of Financial Metrics
# This notebook fetches financial metrics for selected tickers, preprocesses the data, applies KMeans clustering, and visualizes the results.

# %%
from src.kmean_modeling import calculate_inertia, apply_kmeans_and_visualize
from src.data_processing import fetch_financial_metrics
from src.preprocessing import create_preprocessor, preview_transformation
import pandas as pd
import os
os.environ["LOKY_MAX_CPU_COUNT"] = "4"  # Adjust to your physical core count

# %% [markdown]
# ## Define Tickers

# %%
tickers = [
    'VALE3.SA', 'PETR4.SA', 'ITUB4.SA', 'BBDC4.SA', 'BBAS3.SA', 
    'ABEV3.SA', 'RENT3.SA', 'WEGE3.SA', 'ELET3.SA', 'SUZB3.SA', 
    'B3SA3.SA', 'GGBR4.SA', 'EGIE3.SA', 'HAPV3.SA', 'RDOR3.SA', 
    'TOTS3.SA', 'RADL3.SA', 'PRIO3.SA', 'LREN3.SA', 'MGLU3.SA', 
    'VIVT3.SA', 'SBSP3.SA', 'FLRY3.SA', 'GOAU4.SA', 'CPLE6.SA', 
    'ENGI11.SA', 'SANB11.SA', 'BPAC11.SA', 'CXSE3.SA', 'ASAI3.SA'
]

# %% [markdown]
# ## Fetch Financial Metrics

# %%
data = fetch_financial_metrics(tickers)
data.head()
# Out:
#      ticker      roe  debt_to_equity  profit_margins   beta    market_cap  \
# 0  VALE3.SA  0.12837          50.133         0.13814  1.039  245796290560
# 1  PETR4.SA  0.18483          92.443         0.15185  0.319  431181889536
# 2  ITUB4.SA  0.20809             NaN         0.31790  0.302  393762668544
# 3  BBDC4.SA  0.12346             NaN         0.23561  0.384  173472546816
# 4  BBAS3.SA  0.15581             NaN         0.30000  0.319  126098341888
#
#      net_income  total_equity    total_debt
# 0  6.166000e+09  3.452800e+10  4.562400e+10
# 1  7.528000e+09  5.935000e+10  1.222950e+11
# 2  4.108500e+10  2.212840e+11  2.633191e+12
# 3  1.725290e+10  1.689425e+11  1.900542e+12
# 4  2.635886e+10  1.842363e+11  2.214483e+12

# %% [markdown]
# ## Preprocessing (ROE and Debt-to-Equity only)

# %%
num_cols = ['roe', 'debt_to_equity']
for col in num_cols:
    data[col] = pd.to_numeric(data[col], errors='coerce')
    data[col].fillna(data[col].median(), inplace=True)

preprocessor = create_preprocessor(num_cols=num_cols)
scaled_features = preview_transformation(preprocessor, data[num_cols])

df_processed = pd.DataFrame(scaled_features, columns=num_cols)
df_processed['ticker'] = data['ticker'].values
df_processed.head()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_9040\3563364498.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[col].fillna(data[col].median(), inplace=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_9040\3563364498.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[col].fillna(data[col].median(), inplace=True)
#         roe  debt_to_equity    ticker
# 0  0.282531        0.106116  VALE3.SA
# 1  0.397940        0.195812  PETR4.SA
# 2  0.445485        0.163815  ITUB4.SA
# 3  0.272495        0.163815  BBDC4.SA
# 4  0.338621        0.163815  BBAS3.SA

# %% [markdown]
# ## KMeans Clustering and Visualization

# %%
results = apply_kmeans_and_visualize(df_processed, data, optimal_k=4)
# Out:
# Médias dos Clusters (por ROE e D/E quando disponíveis):
#               roe  debt_to_equity
# Cluster
# 0        0.203840      134.779222
# 1        0.176870      471.781000
# 2        0.099872       61.321438
# 3        0.358733       44.973750

# %%
results = apply_kmeans_and_visualize(df_processed, data, optimal_k=5)
# Out:
# Médias dos Clusters (por ROE e D/E quando disponíveis):
#               roe  debt_to_equity
# Cluster
# 0        0.358733       44.973750
# 1        0.079876       56.449091
# 2        0.180315      176.601833
# 3        0.176870      471.781000
# 4        0.183999       64.200625

# %%
results = apply_kmeans_and_visualize(df_processed, data, optimal_k=6)
# Out:
# Médias dos Clusters (por ROE e D/E quando disponíveis):
#               roe  debt_to_equity
# Cluster
# 0        0.213210      202.724667
# 1        0.086594       52.027333
# 2        0.318520       30.636667
# 3        0.176870      471.781000
# 4        0.175376       96.165400
# 5        0.479370       87.985000

# %%
results = apply_kmeans_and_visualize(df_processed, data, optimal_k=8)
# Out:
# Médias dos Clusters (por ROE e D/E quando disponíveis):
#               roe  debt_to_equity
# Cluster
# 0        0.148610       29.022000
# 1        0.213210      202.724667
# 2        0.047702       47.700500
# 3        0.242087       76.991750
# 4        0.176870      471.781000
# 5        0.479370       87.985000
# 6        0.139221      105.897111
# 7        0.323230        7.280000

# %% [markdown]
# ## Show the Head of Each Cluster

# %%
for cluster_id in sorted(results['Cluster'].unique()):
    print(f"\nCluster {cluster_id}:")
    display(results[results['Cluster'] == cluster_id].head())
# Out:
# Cluster 0:
#       ticker      roe  debt_to_equity  profit_margins   beta    market_cap  \
# 1   PETR4.SA  0.18483          92.443         0.15185  0.319  431181889536
# 2   ITUB4.SA  0.20809          77.350         0.31790  0.302  393762668544
# 9   SUZB3.SA  0.18742         227.437         0.15256  0.347   61671845888
# 10  B3SA3.SA  0.24775          75.917         0.49303  0.336   69258878976
# 12  EGIE3.SA  0.24659         209.629         0.25270  0.379   33208260608
#
#       net_income  total_equity    total_debt  scaled_roe  \
# 1   7.528000e+09  5.935000e+10  1.222950e+11    0.397940
# 2   4.108500e+10  2.212840e+11  2.633191e+12    0.445485
# 9  -7.074198e+09  3.241558e+10  1.335205e+11    0.403234
# 10  4.576581e+09  1.838345e+10  2.684540e+10    0.526552
# 12  4.279349e+09  1.228040e+10  3.783190e+10    0.524181
#
#     scaled_debt_to_equity  Cluster
# 1                0.195812        0
# 2                0.163815        0
# 9                0.481996        0
# 10               0.160777        0
# 12               0.444244        0
# Cluster 1:
#       ticker      roe  debt_to_equity  profit_margins  beta   market_cap  \
# 29  ASAI3.SA  0.17687         471.781         0.01209  0.49  12790875136
#
#      net_income  total_equity    total_debt  scaled_roe  \
# 29  769000000.0  5.255000e+09  4.033800e+10    0.381669
#
#     scaled_debt_to_equity  Cluster
# 29                    1.0        1
# Cluster 2:
#      ticker      roe  debt_to_equity  profit_margins   beta    market_cap  \
# 0  VALE3.SA  0.12837          50.133         0.13814  1.039  245796290560
# 3  BBDC4.SA  0.12346          77.350         0.23561  0.384  173472546816
# 4  BBAS3.SA  0.15581          77.350         0.30000  0.319  126098341888
# 5  ABEV3.SA  0.16049           3.388         0.16084  0.362  188510748672
# 6  RENT3.SA  0.09141         169.658         0.05876  0.253   41599188992
#
#      net_income  total_equity    total_debt  scaled_roe  \
# 0  6.166000e+09  3.452800e+10  4.562400e+10    0.282531
# 3  1.725290e+10  1.689425e+11  1.900542e+12    0.272495
# 4  2.635886e+10  1.842363e+11  2.214483e+12    0.338621
# 5  1.443720e+10  9.958050e+10  6.292780e+10    0.348187
# 6  1.813627e+09  2.634271e+10  6.090089e+10    0.206983
#
#    scaled_debt_to_equity  Cluster
# 0               0.106116        2
# 3               0.163815        2
# 4               0.163815        2
# 5               0.007017        2
# 6               0.359506        2
# Cluster 3:
#       ticker      roe  debt_to_equity  profit_margins   beta    market_cap  \
# 7   WEGE3.SA  0.31330          14.482         0.15650  0.053  153520504832
# 17  PRIO3.SA  0.47937          87.985         0.73486  0.981   31199086592
# 21  SBSP3.SA  0.30910          77.350         0.27755  0.137   90339500032
# 28  CXSE3.SA  0.33316           0.078         0.76524  0.328   45329997824
#
#       net_income  total_equity    total_debt  scaled_roe  \
# 7   6.042593e+09  2.312522e+10  1.836448e+10    0.660541
# 17  1.030161e+10  2.592419e+10  2.982197e+10    1.000000
# 21  9.579563e+09  3.692805e+10  4.403738e+10    0.651956
# 28  3.765184e+09  1.288932e+10  1.134692e+09    0.701137
#
#     scaled_debt_to_equity  Cluster
# 7                0.030536        3
# 17               0.186361        3
# 21               0.163815        3
# 28               0.000000        3

# %%
for cluster_id in sorted(results['Cluster'].unique()):
    print(f"\nCluster {cluster_id}:")
    display(results[results['Cluster'] == cluster_id].head())
# Out:
# Cluster 0:
#        ticker      roe  debt_to_equity  profit_margins   beta   market_cap  \
# 9    SUZB3.SA  0.18742         227.437         0.15256  0.347  61671845888
# 12   EGIE3.SA  0.24659         209.629         0.25270  0.379  33208260608
# 25  ENGI11.SA  0.20562         171.108         0.09726  0.354  23249655808
#
#       net_income  total_equity    total_debt  scaled_roe  \
# 9  -7.074198e+09  3.241558e+10  1.335205e+11    0.403234
# 12  4.279349e+09  1.228040e+10  3.783190e+10    0.524181
# 25  3.789678e+09  2.214322e+10  5.503843e+10    0.440436
#
#     scaled_debt_to_equity  Cluster
# 9                0.481996        0
# 12               0.444244        0
# 25               0.362580        0
# Cluster 1:
#       ticker      roe  debt_to_equity  profit_margins   beta    market_cap  \
# 0   VALE3.SA  0.12837          50.133         0.13814  1.039  245796290560
# 3   BBDC4.SA  0.12346          77.350         0.23561  0.384  173472546816
# 5   ABEV3.SA  0.16049           3.388         0.16084  0.362  188510748672
# 8   ELET3.SA  0.05690          63.152         0.15169  0.234  118818570240
# 11  GGBR4.SA  0.05977          35.410         0.04731  0.869   31743322112
#
#       net_income  total_equity    total_debt  scaled_roe  \
# 0   6.166000e+09  3.452800e+10  4.562400e+10    0.282531
# 3   1.725290e+10  1.689425e+11  1.900542e+12    0.272495
# 5   1.443720e+10  9.958050e+10  6.292780e+10    0.348187
# 8   1.037812e+10  1.219998e+11  1.678716e+11    0.136442
# 11  4.566317e+09  5.817379e+10  2.864071e+10    0.142308
#
#     scaled_debt_to_equity  Cluster
# 0                0.106116        1
# 3                0.163815        1
# 5                0.007017        1
# 8                0.133715        1
# 11               0.074903        1
# Cluster 2:
#       ticker      roe  debt_to_equity  profit_margins   beta    market_cap  \
# 7   WEGE3.SA  0.31330          14.482         0.15650  0.053  153520504832
# 21  SBSP3.SA  0.30910          77.350         0.27755  0.137   90339500032
# 28  CXSE3.SA  0.33316           0.078         0.76524  0.328   45329997824
#
#       net_income  total_equity    total_debt  scaled_roe  \
# 7   6.042593e+09  2.312522e+10  1.836448e+10    0.660541
# 21  9.579563e+09  3.692805e+10  4.403738e+10    0.651956
# 28  3.765184e+09  1.288932e+10  1.134692e+09    0.701137
#
#     scaled_debt_to_equity  Cluster
# 7                0.030536        2
# 21               0.163815        2
# 28               0.000000        2
# Cluster 3:
#       ticker      roe  debt_to_equity  profit_margins  beta   market_cap  \
# 29  ASAI3.SA  0.17687         471.781         0.01209  0.49  12790875136
#
#      net_income  total_equity    total_debt  scaled_roe  \
# 29  769000000.0  5.255000e+09  4.033800e+10    0.381669
#
#     scaled_debt_to_equity  Cluster
# 29                    1.0        3
# Cluster 4:
#       ticker      roe  debt_to_equity  profit_margins   beta    market_cap  \
# 1   PETR4.SA  0.18483          92.443         0.15185  0.319  431181889536
# 2   ITUB4.SA  0.20809          77.350         0.31790  0.302  393762668544
# 4   BBAS3.SA  0.15581          77.350         0.30000  0.319  126098341888
# 6   RENT3.SA  0.09141         169.658         0.05876  0.253   41599188992
# 10  B3SA3.SA  0.24775          75.917         0.49303  0.336   69258878976
#
#       net_income  total_equity    total_debt  scaled_roe  \
# 1   7.528000e+09  5.935000e+10  1.222950e+11    0.397940
# 2   4.108500e+10  2.212840e+11  2.633191e+12    0.445485
# 4   2.635886e+10  1.842363e+11  2.214483e+12    0.338621
# 6   1.813627e+09  2.634271e+10  6.090089e+10    0.206983
# 10  4.576581e+09  1.838345e+10  2.684540e+10    0.526552
#
#     scaled_debt_to_equity  Cluster
# 1                0.195812        4
# 2                0.163815        4
# 4                0.163815        4
# 6                0.359506        4
# 10               0.160777        4
# Cluster 5:
#       ticker      roe  debt_to_equity  profit_margins   beta   market_cap  \
# 17  PRIO3.SA  0.47937          87.985         0.73486  0.981  31199086592
#
#       net_income  total_equity    total_debt  scaled_roe  \
# 17  1.030161e+10  2.592419e+10  2.982197e+10         1.0
#
#     scaled_debt_to_equity  Cluster
# 17               0.186361        5

# %%
for cluster_id in sorted(results['Cluster'].unique()):
    print(f"\nCluster {cluster_id}:")
    display(results[results['Cluster'] == cluster_id].head())
# Out:
# Cluster 0:
#       ticker      roe  debt_to_equity  profit_margins   beta    market_cap  \
# 0   VALE3.SA  0.12837          50.133         0.13814  1.039  245796290560
# 5   ABEV3.SA  0.16049           3.388         0.16084  0.362  188510748672
# 15  TOTS3.SA  0.17288          32.457         0.15139  0.600   26989641728
# 18  LREN3.SA  0.13270          30.110         0.08864  0.593   15059216384
#
#       net_income  total_equity    total_debt  scaled_roe  \
# 0   6.166000e+09  3.452800e+10  4.562400e+10    0.282531
# 5   1.443720e+10  9.958050e+10  6.292780e+10    0.348187
# 15  7.175130e+08  4.987121e+09  3.544600e+09    0.373513
# 18  1.196668e+09  1.077295e+10  9.591639e+09    0.291382
#
#     scaled_debt_to_equity  Cluster
# 0                0.106116        0
# 5                0.007017        0
# 15               0.068643        0
# 18               0.063667        0
# Cluster 1:
#        ticker      roe  debt_to_equity  profit_margins   beta   market_cap  \
# 9    SUZB3.SA  0.18742         227.437         0.15256  0.347  61671845888
# 12   EGIE3.SA  0.24659         209.629         0.25270  0.379  33208260608
# 25  ENGI11.SA  0.20562         171.108         0.09726  0.354  23249655808
#
#       net_income  total_equity    total_debt  scaled_roe  \
# 9  -7.074198e+09  3.241558e+10  1.335205e+11    0.403234
# 12  4.279349e+09  1.228040e+10  3.783190e+10    0.524181
# 25  3.789678e+09  2.214322e+10  5.503843e+10    0.440436
#
#     scaled_debt_to_equity  Cluster
# 9                0.481996        1
# 12               0.444244        1
# 25               0.362580        1
# Cluster 2:
#       ticker      roe  debt_to_equity  profit_margins   beta    market_cap  \
# 8   ELET3.SA  0.05690          63.152         0.15169  0.234  118818570240
# 11  GGBR4.SA  0.05977          35.410         0.04731  0.869   31743322112
# 13  HAPV3.SA -0.00985          34.667        -0.01623  0.397   17748938752
# 19  MGLU3.SA  0.03496          87.740         0.01006  1.270    7461074944
# 20  VIVT3.SA  0.08485          29.855         0.10117  0.383  109221904384
#
#       net_income  total_equity    total_debt  scaled_roe  \
# 8   1.037812e+10  1.219998e+11  1.678716e+11    0.136442
# 11  4.566317e+09  5.817379e+10  2.864071e+10    0.142308
# 13 -6.493010e+08  4.867692e+10  2.482272e+10    0.000000
# 19  4.487170e+08  1.131926e+10  2.599260e+10    0.091595
# 20  5.547948e+09  6.979950e+10  5.514118e+10    0.193573
#
#     scaled_debt_to_equity  Cluster
# 8                0.133715        2
# 11               0.074903        2
# 13               0.073328        2
# 19               0.185842        2
# 20               0.063127        2
# Cluster 3:
#        ticker      roe  debt_to_equity  profit_margins   beta    market_cap  \
# 2    ITUB4.SA  0.20809          77.350         0.31790  0.302  393762668544
# 10   B3SA3.SA  0.24775          75.917         0.49303  0.336   69258878976
# 21   SBSP3.SA  0.30910          77.350         0.27755  0.137   90339500032
# 27  BPAC11.SA  0.20341          77.350         0.33132  0.529  161289519104
#
#       net_income  total_equity    total_debt  scaled_roe  \
# 2   4.108500e+10  2.212840e+11  2.633191e+12    0.445485
# 10  4.576581e+09  1.838345e+10  2.684540e+10    0.526552
# 21  9.579563e+09  3.692805e+10  4.403738e+10    0.651956
# 27  1.178939e+10  6.353387e+10  5.833079e+11    0.435918
#
#     scaled_debt_to_equity  Cluster
# 2                0.163815        3
# 10               0.160777        3
# 21               0.163815        3
# 27               0.163815        3
# Cluster 4:
#       ticker      roe  debt_to_equity  profit_margins  beta   market_cap  \
# 29  ASAI3.SA  0.17687         471.781         0.01209  0.49  12790875136
#
#      net_income  total_equity    total_debt  scaled_roe  \
# 29  769000000.0  5.255000e+09  4.033800e+10    0.381669
#
#     scaled_debt_to_equity  Cluster
# 29                    1.0        4
# Cluster 5:
#       ticker      roe  debt_to_equity  profit_margins   beta   market_cap  \
# 17  PRIO3.SA  0.47937          87.985         0.73486  0.981  31199086592
#
#       net_income  total_equity    total_debt  scaled_roe  \
# 17  1.030161e+10  2.592419e+10  2.982197e+10         1.0
#
#     scaled_debt_to_equity  Cluster
# 17               0.186361        5
# Cluster 6:
#       ticker      roe  debt_to_equity  profit_margins   beta    market_cap  \
# 1   PETR4.SA  0.18483          92.443         0.15185  0.319  431181889536
# 3   BBDC4.SA  0.12346          77.350         0.23561  0.384  173472546816
# 4   BBAS3.SA  0.15581          77.350         0.30000  0.319  126098341888
# 6   RENT3.SA  0.09141         169.658         0.05876  0.253   41599188992
# 14  RDOR3.SA  0.15899         155.841         0.07788  1.021   92859760640
#
#       net_income  total_equity    total_debt  scaled_roe  \
# 1   7.528000e+09  5.935000e+10  1.222950e+11    0.397940
# 3   1.725290e+10  1.689425e+11  1.900542e+12    0.272495
# 4   2.635886e+10  1.842363e+11  2.214483e+12    0.338621
# 6   1.813627e+09  2.634271e+10  6.090089e+10    0.206983
# 14  3.846945e+09  2.670187e+10  7.589601e+10    0.345121
#
#     scaled_debt_to_equity  Cluster
# 1                0.195812        6
# 3                0.163815        6
# 4                0.163815        6
# 6                0.359506        6
# 14               0.330214        6
# Cluster 7:
#       ticker      roe  debt_to_equity  profit_margins   beta    market_cap  \
# 7   WEGE3.SA  0.31330          14.482         0.15650  0.053  153520504832
# 28  CXSE3.SA  0.33316           0.078         0.76524  0.328   45329997824
#
#       net_income  total_equity    total_debt  scaled_roe  \
# 7   6.042593e+09  2.312522e+10  1.836448e+10    0.660541
# 28  3.765184e+09  1.288932e+10  1.134692e+09    0.701137
#
#     scaled_debt_to_equity  Cluster
# 7                0.030536        7
# 28               0.000000        7
